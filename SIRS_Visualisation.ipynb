# %% [markdown]
# ## SIRS Animation

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LinearSegmentedColormap
from SIRS_class import SIRS_Lattice
matplotlib.use('TKAgg')

# define custom colormap: susceptible (0) = red, infected (-1) = black, recovered (1) = blue
colors = [(0, 0, 0),    # black (infected)
          (1, 0, 0),    # red (susceptible)
          (0, 0, 1)]    # blue (recovered)

# create a custom colormap that maps -1, 0, 1 to the colors above
cmap = LinearSegmentedColormap.from_list('sirs_cmap', colors, N=3)

# %%
rng = random.default_rng()

# fixed parameters
N = 50
n_step = 500
lattice = random.randint(low=-1, high=2, size=(N,N)) # randomly initialise lattice

system = SIRS_Lattice(lattice)

# variables
p1, p2, p3 = [.8, .1, .01]
#p1, p2, p3 = SIRS_Lattice.set_initialisation_wave()
#p1, p2, p3 = SIRS_Lattice.set_initialisation_dynamiceq()
#p1, p2, p3 = SIRS_Lattice.set_initialisation_absorbing()

# %%
susceptible_sites = []
infected_sites = []
recovered_sites = []
sweep_array = []

I_fraction_array = []

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
im = ax1.imshow(system.lattice, animated=True, vmin=-1, vmax=1, cmap=cmap)
fig.colorbar(im, ax=ax1, ticks=[-1, 0, 1], 
             label='I, S, R')
line, = ax2.plot([], [])  # empty line plot to start

for sweep in range(n_step):
    for _ in range(N**2):
        site = random.choice(N,2)
        bool_test, updated_site, updated_state = system.update_step(site, p1,p2,p3)

        i, j = updated_site

        if bool_test:
            lattice[i][j] = updated_state
            system = SIRS_Lattice(lattice)
        
    susceptible, infected, recovered = system.count_states()
    I_frac = system.get_I_fraction()
    print(f'Sweep: {sweep}, Fraction of infected sites: {I_frac}')

    I_fraction_array.append(I_frac)
    sweep_array.append(sweep)
    susceptible_sites.append(susceptible)
    infected_sites.append(infected)
    recovered_sites.append(recovered)    

    # animation
    ax1.cla()
    im=ax1.imshow(system.lattice, animated=True, vmin=-1, vmax=1, cmap=cmap)
    ax1.set_title('SIRS Animation')

    # update states graph
    ax2.cla()  # clear the axes
    ax2.plot(sweep_array, susceptible_sites, 'r-', label='S') 
    ax2.plot(sweep_array, infected_sites, 'k-', label='I')       
    ax2.plot(sweep_array, recovered_sites, 'b-', label='R')    
    ax2.legend()
    ax2.relim()  # recalculate limits
    ax2.autoscale_view()  # autoscale the view
    ax2.set_title('Real Time of States')
    ax2.set_xlabel('Sweeps')
    ax2.set_ylabel('Number of States')

    plt.draw()
    plt.pause(0.0001)

print(f'\nAverage Infection (Fraction): {system.get_I_average(I_fraction_array)}')
print(f'\nVariance Infection (Fraction): {system.get_I_variance(np.array(I_fraction_array))}')
# Out:
# Sweep: 0, Fraction of infected sites: 0.4448
# Sweep: 1, Fraction of infected sites: 0.482
# Sweep: 2, Fraction of infected sites: 0.4772
# Sweep: 3, Fraction of infected sites: 0.452
# Sweep: 4, Fraction of infected sites: 0.4256
# Sweep: 5, Fraction of infected sites: 0.3844
# Sweep: 6, Fraction of infected sites: 0.3504
# Sweep: 7, Fraction of infected sites: 0.3236
# Sweep: 8, Fraction of infected sites: 0.2972
# Sweep: 9, Fraction of infected sites: 0.268
# Sweep: 10, Fraction of infected sites: 0.2528
# Sweep: 11, Fraction of infected sites: 0.2348
# Sweep: 12, Fraction of infected sites: 0.2156
# Sweep: 13, Fraction of infected sites: 0.2
# Sweep: 14, Fraction of infected sites: 0.182
# Sweep: 15, Fraction of infected sites: 0.1692
# Sweep: 16, Fraction of infected sites: 0.16
# Sweep: 17, Fraction of infected sites: 0.1528
# Sweep: 18, Fraction of infected sites: 0.142
# Sweep: 19, Fraction of infected sites: 0.1312
# Sweep: 20, Fraction of infected sites: 0.1228
# Sweep: 21, Fraction of infected sites: 0.1208
# Sweep: 22, Fraction of infected sites: 0.118
# Sweep: 23, Fraction of infected sites: 0.1108
# Sweep: 24, Fraction of infected sites: 0.1012
# Sweep: 25, Fraction of infected sites: 0.0936
# Sweep: 26, Fraction of infected sites: 0.0936
# Sweep: 27, Fraction of infected sites: 0.0844
# Sweep: 28, Fraction of infected sites: 0.0788
# Sweep: 29, Fraction of infected sites: 0.0748
# Sweep: 30, Fraction of infected sites: 0.0716
# Sweep: 31, Fraction of infected sites: 0.0652
# Sweep: 32, Fraction of infected sites: 0.0628
# Sweep: 33, Fraction of infected sites: 0.06
# Sweep: 34, Fraction of infected sites: 0.0552
# Sweep: 35, Fraction of infected sites: 0.0504
# Sweep: 36, Fraction of infected sites: 0.0496
# Sweep: 37, Fraction of infected sites: 0.0468
# Sweep: 38, Fraction of infected sites: 0.042
# Sweep: 39, Fraction of infected sites: 0.0408
# Sweep: 40, Fraction of infected sites: 0.0412
# Sweep: 41, Fraction of infected sites: 0.0384
# Sweep: 42, Fraction of infected sites: 0.0376
# Sweep: 43, Fraction of infected sites: 0.0324
# Sweep: 44, Fraction of infected sites: 0.0312
# Sweep: 45, Fraction of infected sites: 0.0288
# Sweep: 46, Fraction of infected sites: 0.0284
# Sweep: 47, Fraction of infected sites: 0.028
# Sweep: 48, Fraction of infected sites: 0.0252
# Sweep: 49, Fraction of infected sites: 0.0244
# Sweep: 50, Fraction of infected sites: 0.0256
# Sweep: 51, Fraction of infected sites: 0.0248
# Sweep: 52, Fraction of infected sites: 0.0244
# Sweep: 53, Fraction of infected sites: 0.0224
# Sweep: 54, Fraction of infected sites: 0.0232
# Sweep: 55, Fraction of infected sites: 0.0224
# Sweep: 56, Fraction of infected sites: 0.0216
# Sweep: 57, Fraction of infected sites: 0.0204
# Sweep: 58, Fraction of infected sites: 0.0224
# Sweep: 59, Fraction of infected sites: 0.0244
# Sweep: 60, Fraction of infected sites: 0.024
# Sweep: 61, Fraction of infected sites: 0.0244
# Sweep: 62, Fraction of infected sites: 0.0216
# Sweep: 63, Fraction of infected sites: 0.02
# Sweep: 64, Fraction of infected sites: 0.0212
# Sweep: 65, Fraction of infected sites: 0.0216
# Sweep: 66, Fraction of infected sites: 0.0208
# Sweep: 67, Fraction of infected sites: 0.0216
# Sweep: 68, Fraction of infected sites: 0.0228
# Sweep: 69, Fraction of infected sites: 0.0216
# Sweep: 70, Fraction of infected sites: 0.0232
# Sweep: 71, Fraction of infected sites: 0.0248
# Sweep: 72, Fraction of infected sites: 0.0256
# Sweep: 73, Fraction of infected sites: 0.0224
# Sweep: 74, Fraction of infected sites: 0.0204
# Sweep: 75, Fraction of infected sites: 0.0192
# Sweep: 76, Fraction of infected sites: 0.0196
# Sweep: 77, Fraction of infected sites: 0.0192
# Sweep: 78, Fraction of infected sites: 0.0212
# Sweep: 79, Fraction of infected sites: 0.0212
# Sweep: 80, Fraction of infected sites: 0.0216
# Sweep: 81, Fraction of infected sites: 0.02
# Sweep: 82, Fraction of infected sites: 0.0208
# Sweep: 83, Fraction of infected sites: 0.022
# Sweep: 84, Fraction of infected sites: 0.022
# Sweep: 85, Fraction of infected sites: 0.0224
# Sweep: 86, Fraction of infected sites: 0.0228
# Sweep: 87, Fraction of infected sites: 0.02
# Sweep: 88, Fraction of infected sites: 0.0192
# Sweep: 89, Fraction of infected sites: 0.0196
# Sweep: 90, Fraction of infected sites: 0.0196
# Sweep: 91, Fraction of infected sites: 0.0204
# Sweep: 92, Fraction of infected sites: 0.0212
# Sweep: 93, Fraction of infected sites: 0.02
# Sweep: 94, Fraction of infected sites: 0.0196
# Sweep: 95, Fraction of infected sites: 0.018
# Sweep: 96, Fraction of infected sites: 0.0164
# Sweep: 97, Fraction of infected sites: 0.0144
# Sweep: 98, Fraction of infected sites: 0.0136
# Sweep: 99, Fraction of infected sites: 0.0124
# Sweep: 100, Fraction of infected sites: 0.012
# Sweep: 101, Fraction of infected sites: 0.01
# Sweep: 102, Fraction of infected sites: 0.0088
# Sweep: 103, Fraction of infected sites: 0.0084
# Sweep: 104, Fraction of infected sites: 0.008
# Sweep: 105, Fraction of infected sites: 0.0076
# Sweep: 106, Fraction of infected sites: 0.0076
# Sweep: 107, Fraction of infected sites: 0.0072
# Sweep: 108, Fraction of infected sites: 0.0072
# Sweep: 109, Fraction of infected sites: 0.006
# Sweep: 110, Fraction of infected sites: 0.006
# Sweep: 111, Fraction of infected sites: 0.006
# Sweep: 112, Fraction of infected sites: 0.0056
# Sweep: 113, Fraction of infected sites: 0.006
# Sweep: 114, Fraction of infected sites: 0.0076
# Sweep: 115, Fraction of infected sites: 0.008
# Sweep: 116, Fraction of infected sites: 0.0124
# Sweep: 117, Fraction of infected sites: 0.0144
# Sweep: 118, Fraction of infected sites: 0.0148
# Sweep: 119, Fraction of infected sites: 0.022
# Sweep: 120, Fraction of infected sites: 0.028
# Sweep: 121, Fraction of infected sites: 0.0288
# Sweep: 122, Fraction of infected sites: 0.0348
# Sweep: 123, Fraction of infected sites: 0.0376
# Sweep: 124, Fraction of infected sites: 0.0404
# Sweep: 125, Fraction of infected sites: 0.042
# Sweep: 126, Fraction of infected sites: 0.0436
# Sweep: 127, Fraction of infected sites: 0.0432
# Sweep: 128, Fraction of infected sites: 0.0452
# Sweep: 129, Fraction of infected sites: 0.0464
# Sweep: 130, Fraction of infected sites: 0.048
# Sweep: 131, Fraction of infected sites: 0.0488
# Sweep: 132, Fraction of infected sites: 0.0472
# Sweep: 133, Fraction of infected sites: 0.05
# Sweep: 134, Fraction of infected sites: 0.0524
# Sweep: 135, Fraction of infected sites: 0.0528
# Sweep: 136, Fraction of infected sites: 0.0532
# Sweep: 137, Fraction of infected sites: 0.0556
# Sweep: 138, Fraction of infected sites: 0.0572
# Sweep: 139, Fraction of infected sites: 0.0612
# Sweep: 140, Fraction of infected sites: 0.0596
# Sweep: 141, Fraction of infected sites: 0.0592
# Sweep: 142, Fraction of infected sites: 0.0592
# Sweep: 143, Fraction of infected sites: 0.0584
# Sweep: 144, Fraction of infected sites: 0.0636
# Sweep: 145, Fraction of infected sites: 0.0704
# Sweep: 146, Fraction of infected sites: 0.078
# Sweep: 147, Fraction of infected sites: 0.0804
# Sweep: 148, Fraction of infected sites: 0.0908
# Sweep: 149, Fraction of infected sites: 0.1056
# Sweep: 150, Fraction of infected sites: 0.1108
# Sweep: 151, Fraction of infected sites: 0.1152
# Sweep: 152, Fraction of infected sites: 0.124
# Sweep: 153, Fraction of infected sites: 0.132
# Sweep: 154, Fraction of infected sites: 0.1428
# Sweep: 155, Fraction of infected sites: 0.1556
# Sweep: 156, Fraction of infected sites: 0.1696
# Sweep: 157, Fraction of infected sites: 0.1848
# Sweep: 158, Fraction of infected sites: 0.1976
# Sweep: 159, Fraction of infected sites: 0.2024
# Sweep: 160, Fraction of infected sites: 0.2084
# Sweep: 161, Fraction of infected sites: 0.2188
# Sweep: 162, Fraction of infected sites: 0.2216
# Sweep: 163, Fraction of infected sites: 0.2292
# Sweep: 164, Fraction of infected sites: 0.2284
# Sweep: 165, Fraction of infected sites: 0.2252
# Sweep: 166, Fraction of infected sites: 0.222
# Sweep: 167, Fraction of infected sites: 0.2136
# Sweep: 168, Fraction of infected sites: 0.2024
# Sweep: 169, Fraction of infected sites: 0.1952
# Sweep: 170, Fraction of infected sites: 0.1864
# Sweep: 171, Fraction of infected sites: 0.1796
# Sweep: 172, Fraction of infected sites: 0.17
# Sweep: 173, Fraction of infected sites: 0.156
# Sweep: 174, Fraction of infected sites: 0.1468
# Sweep: 175, Fraction of infected sites: 0.14
# Sweep: 176, Fraction of infected sites: 0.1304
# Sweep: 177, Fraction of infected sites: 0.1216
# Sweep: 178, Fraction of infected sites: 0.1108
# Sweep: 179, Fraction of infected sites: 0.104
# Sweep: 180, Fraction of infected sites: 0.0976
# Sweep: 181, Fraction of infected sites: 0.0912
# Sweep: 182, Fraction of infected sites: 0.0844
# Sweep: 183, Fraction of infected sites: 0.078
# Sweep: 184, Fraction of infected sites: 0.0716
# Sweep: 185, Fraction of infected sites: 0.0692
# Sweep: 186, Fraction of infected sites: 0.068
# Sweep: 187, Fraction of infected sites: 0.064
# Sweep: 188, Fraction of infected sites: 0.0616
# Sweep: 189, Fraction of infected sites: 0.0588
# Sweep: 190, Fraction of infected sites: 0.0536
# Sweep: 191, Fraction of infected sites: 0.0476
# Sweep: 192, Fraction of infected sites: 0.0416
# Sweep: 193, Fraction of infected sites: 0.04
# Sweep: 194, Fraction of infected sites: 0.0404
# Sweep: 195, Fraction of infected sites: 0.0352
# Sweep: 196, Fraction of infected sites: 0.0324
# Sweep: 197, Fraction of infected sites: 0.0304
# Sweep: 198, Fraction of infected sites: 0.0292
# Sweep: 199, Fraction of infected sites: 0.028
# Sweep: 200, Fraction of infected sites: 0.0272
# Sweep: 201, Fraction of infected sites: 0.0252
# Sweep: 202, Fraction of infected sites: 0.0264
# Sweep: 203, Fraction of infected sites: 0.0256
# Sweep: 204, Fraction of infected sites: 0.0244
# Sweep: 205, Fraction of infected sites: 0.0256
# Sweep: 206, Fraction of infected sites: 0.0244
# Sweep: 207, Fraction of infected sites: 0.0216
# Sweep: 208, Fraction of infected sites: 0.0204
# Sweep: 209, Fraction of infected sites: 0.0184
# Sweep: 210, Fraction of infected sites: 0.0176
# Sweep: 211, Fraction of infected sites: 0.0148
# Sweep: 212, Fraction of infected sites: 0.0132
# Sweep: 213, Fraction of infected sites: 0.0128
# Sweep: 214, Fraction of infected sites: 0.0124
# Sweep: 215, Fraction of infected sites: 0.0124
# Sweep: 216, Fraction of infected sites: 0.0128
# Sweep: 217, Fraction of infected sites: 0.0112
# Sweep: 218, Fraction of infected sites: 0.012
# Sweep: 219, Fraction of infected sites: 0.012
# Sweep: 220, Fraction of infected sites: 0.012
# Sweep: 221, Fraction of infected sites: 0.01
# Sweep: 222, Fraction of infected sites: 0.0088
# Sweep: 223, Fraction of infected sites: 0.0084
# Sweep: 224, Fraction of infected sites: 0.0084
# Sweep: 225, Fraction of infected sites: 0.008
# Sweep: 226, Fraction of infected sites: 0.0076
# Sweep: 227, Fraction of infected sites: 0.0072
# Sweep: 228, Fraction of infected sites: 0.0064
# Sweep: 229, Fraction of infected sites: 0.0056
# Sweep: 230, Fraction of infected sites: 0.0056
# Sweep: 231, Fraction of infected sites: 0.0044
# Sweep: 232, Fraction of infected sites: 0.0036
# Sweep: 233, Fraction of infected sites: 0.0036
# Sweep: 234, Fraction of infected sites: 0.0032
# Sweep: 235, Fraction of infected sites: 0.0036
# Sweep: 236, Fraction of infected sites: 0.0044
# Sweep: 237, Fraction of infected sites: 0.0048
# Sweep: 238, Fraction of infected sites: 0.004
# Sweep: 239, Fraction of infected sites: 0.0048
# Sweep: 240, Fraction of infected sites: 0.0048
# Sweep: 241, Fraction of infected sites: 0.0048
# Sweep: 242, Fraction of infected sites: 0.0044
# Sweep: 243, Fraction of infected sites: 0.004
# Sweep: 244, Fraction of infected sites: 0.0036
# Sweep: 245, Fraction of infected sites: 0.0036
# Sweep: 246, Fraction of infected sites: 0.0032
# Sweep: 247, Fraction of infected sites: 0.0032
# Sweep: 248, Fraction of infected sites: 0.0032
# Sweep: 249, Fraction of infected sites: 0.0024
# Sweep: 250, Fraction of infected sites: 0.0024
# Sweep: 251, Fraction of infected sites: 0.0024
# Sweep: 252, Fraction of infected sites: 0.0024
# Sweep: 253, Fraction of infected sites: 0.0024
# Sweep: 254, Fraction of infected sites: 0.002
# Sweep: 255, Fraction of infected sites: 0.002
# Sweep: 256, Fraction of infected sites: 0.0024
# Sweep: 257, Fraction of infected sites: 0.0024
# Sweep: 258, Fraction of infected sites: 0.002
# Sweep: 259, Fraction of infected sites: 0.0024
# Sweep: 260, Fraction of infected sites: 0.0032
# Sweep: 261, Fraction of infected sites: 0.0048
# Sweep: 262, Fraction of infected sites: 0.0064
# Sweep: 263, Fraction of infected sites: 0.008
# Sweep: 264, Fraction of infected sites: 0.0124
# Sweep: 265, Fraction of infected sites: 0.0148
# Sweep: 266, Fraction of infected sites: 0.016
# Sweep: 267, Fraction of infected sites: 0.0256
# Sweep: 268, Fraction of infected sites: 0.03
# Sweep: 269, Fraction of infected sites: 0.038
# Sweep: 270, Fraction of infected sites: 0.0412
# Sweep: 271, Fraction of infected sites: 0.0412
# Sweep: 272, Fraction of infected sites: 0.0396
# Sweep: 273, Fraction of infected sites: 0.038
# Sweep: 274, Fraction of infected sites: 0.0376
# Sweep: 275, Fraction of infected sites: 0.0388
# Sweep: 276, Fraction of infected sites: 0.0396
# Sweep: 277, Fraction of infected sites: 0.0424
# Sweep: 278, Fraction of infected sites: 0.0464
# Sweep: 279, Fraction of infected sites: 0.0468
# Sweep: 280, Fraction of infected sites: 0.0528
# Sweep: 281, Fraction of infected sites: 0.0576
# Sweep: 282, Fraction of infected sites: 0.0624
# Sweep: 283, Fraction of infected sites: 0.0648
# Sweep: 284, Fraction of infected sites: 0.0716
# Sweep: 285, Fraction of infected sites: 0.0772
# Sweep: 286, Fraction of infected sites: 0.0848
# Sweep: 287, Fraction of infected sites: 0.0928
# Sweep: 288, Fraction of infected sites: 0.1076
# Sweep: 289, Fraction of infected sites: 0.118
# Sweep: 290, Fraction of infected sites: 0.1248
# Sweep: 291, Fraction of infected sites: 0.1384
# Sweep: 292, Fraction of infected sites: 0.1432
# Sweep: 293, Fraction of infected sites: 0.144
# Sweep: 294, Fraction of infected sites: 0.1464
# Sweep: 295, Fraction of infected sites: 0.1452
# Sweep: 296, Fraction of infected sites: 0.146
# Sweep: 297, Fraction of infected sites: 0.1536
# Sweep: 298, Fraction of infected sites: 0.1604
# Sweep: 299, Fraction of infected sites: 0.1688
# Sweep: 300, Fraction of infected sites: 0.1708
# Sweep: 301, Fraction of infected sites: 0.17
# Sweep: 302, Fraction of infected sites: 0.176
# Sweep: 303, Fraction of infected sites: 0.1816
# Sweep: 304, Fraction of infected sites: 0.18
# Sweep: 305, Fraction of infected sites: 0.184
# Sweep: 306, Fraction of infected sites: 0.19
# Sweep: 307, Fraction of infected sites: 0.1944
# Sweep: 308, Fraction of infected sites: 0.1976
# Sweep: 309, Fraction of infected sites: 0.1988
# Sweep: 310, Fraction of infected sites: 0.1988
# Sweep: 311, Fraction of infected sites: 0.19
# Sweep: 312, Fraction of infected sites: 0.1892
# Sweep: 313, Fraction of infected sites: 0.1832
# Sweep: 314, Fraction of infected sites: 0.1768
# Sweep: 315, Fraction of infected sites: 0.1684
# Sweep: 316, Fraction of infected sites: 0.1636
# Sweep: 317, Fraction of infected sites: 0.1568
# Sweep: 318, Fraction of infected sites: 0.1432
# Sweep: 319, Fraction of infected sites: 0.1352
# Sweep: 320, Fraction of infected sites: 0.128
# Sweep: 321, Fraction of infected sites: 0.1212
# Sweep: 322, Fraction of infected sites: 0.116
# Sweep: 323, Fraction of infected sites: 0.11
# Sweep: 324, Fraction of infected sites: 0.1044
# Sweep: 325, Fraction of infected sites: 0.1008
# Sweep: 326, Fraction of infected sites: 0.098
# Sweep: 327, Fraction of infected sites: 0.09
# Sweep: 328, Fraction of infected sites: 0.0844
# Sweep: 329, Fraction of infected sites: 0.0796
# Sweep: 330, Fraction of infected sites: 0.076
# Sweep: 331, Fraction of infected sites: 0.072
# Sweep: 332, Fraction of infected sites: 0.0648
# Sweep: 333, Fraction of infected sites: 0.0616
# Sweep: 334, Fraction of infected sites: 0.0552
# Sweep: 335, Fraction of infected sites: 0.0524
# Sweep: 336, Fraction of infected sites: 0.05
# Sweep: 337, Fraction of infected sites: 0.0472
# Sweep: 338, Fraction of infected sites: 0.0448
# Sweep: 339, Fraction of infected sites: 0.0404
# Sweep: 340, Fraction of infected sites: 0.0392
# Sweep: 341, Fraction of infected sites: 0.0376
# Sweep: 342, Fraction of infected sites: 0.0376
# Sweep: 343, Fraction of infected sites: 0.034
# Sweep: 344, Fraction of infected sites: 0.0316
# Sweep: 345, Fraction of infected sites: 0.0296
# Sweep: 346, Fraction of infected sites: 0.0276
# Sweep: 347, Fraction of infected sites: 0.0252
# Sweep: 348, Fraction of infected sites: 0.0232
# Sweep: 349, Fraction of infected sites: 0.0208
# Sweep: 350, Fraction of infected sites: 0.0196
# Sweep: 351, Fraction of infected sites: 0.0184
# Sweep: 352, Fraction of infected sites: 0.0164
# Sweep: 353, Fraction of infected sites: 0.0156
# Sweep: 354, Fraction of infected sites: 0.0148
# Sweep: 355, Fraction of infected sites: 0.0136
# Sweep: 356, Fraction of infected sites: 0.012
# Sweep: 357, Fraction of infected sites: 0.01
# Sweep: 358, Fraction of infected sites: 0.0084
# Sweep: 359, Fraction of infected sites: 0.0068
# Sweep: 360, Fraction of infected sites: 0.0068
# Sweep: 361, Fraction of infected sites: 0.0068
# Sweep: 362, Fraction of infected sites: 0.0064
# Sweep: 363, Fraction of infected sites: 0.0064
# Sweep: 364, Fraction of infected sites: 0.006
# Sweep: 365, Fraction of infected sites: 0.0044
# Sweep: 366, Fraction of infected sites: 0.0036
# Sweep: 367, Fraction of infected sites: 0.0032
# Sweep: 368, Fraction of infected sites: 0.0032
# Sweep: 369, Fraction of infected sites: 0.0028
# Sweep: 370, Fraction of infected sites: 0.0024
# Sweep: 371, Fraction of infected sites: 0.0024
# Sweep: 372, Fraction of infected sites: 0.002
# Sweep: 373, Fraction of infected sites: 0.0024
# Sweep: 374, Fraction of infected sites: 0.002
# Sweep: 375, Fraction of infected sites: 0.002
# Sweep: 376, Fraction of infected sites: 0.0016
# Sweep: 377, Fraction of infected sites: 0.0012
# Sweep: 378, Fraction of infected sites: 0.0008
# Sweep: 379, Fraction of infected sites: 0.0012
# Sweep: 380, Fraction of infected sites: 0.0008
# Sweep: 381, Fraction of infected sites: 0.0008
# Sweep: 382, Fraction of infected sites: 0.0008
# Sweep: 383, Fraction of infected sites: 0.0008
# Sweep: 384, Fraction of infected sites: 0.0004
# Sweep: 385, Fraction of infected sites: 0.0004
# Sweep: 386, Fraction of infected sites: 0.0004
# Sweep: 387, Fraction of infected sites: 0.0004
# Sweep: 388, Fraction of infected sites: 0.0004
# Sweep: 389, Fraction of infected sites: 0.0
# Sweep: 390, Fraction of infected sites: 0.0
# Sweep: 391, Fraction of infected sites: 0.0
# Sweep: 392, Fraction of infected sites: 0.0
# Sweep: 393, Fraction of infected sites: 0.0
# Sweep: 394, Fraction of infected sites: 0.0
# Sweep: 395, Fraction of infected sites: 0.0
# Sweep: 396, Fraction of infected sites: 0.0
# Sweep: 397, Fraction of infected sites: 0.0
# Sweep: 398, Fraction of infected sites: 0.0
# Sweep: 399, Fraction of infected sites: 0.0
# Sweep: 400, Fraction of infected sites: 0.0
# Sweep: 401, Fraction of infected sites: 0.0
# Sweep: 402, Fraction of infected sites: 0.0
# Sweep: 403, Fraction of infected sites: 0.0
# Sweep: 404, Fraction of infected sites: 0.0
# Sweep: 405, Fraction of infected sites: 0.0
# Sweep: 406, Fraction of infected sites: 0.0
# Sweep: 407, Fraction of infected sites: 0.0
# Sweep: 408, Fraction of infected sites: 0.0
# Sweep: 409, Fraction of infected sites: 0.0
# Sweep: 410, Fraction of infected sites: 0.0
# Sweep: 411, Fraction of infected sites: 0.0
# Sweep: 412, Fraction of infected sites: 0.0
# Sweep: 413, Fraction of infected sites: 0.0
# Sweep: 414, Fraction of infected sites: 0.0
# Sweep: 415, Fraction of infected sites: 0.0
# Sweep: 416, Fraction of infected sites: 0.0
# Sweep: 417, Fraction of infected sites: 0.0
# Sweep: 418, Fraction of infected sites: 0.0
# Sweep: 419, Fraction of infected sites: 0.0
# Sweep: 420, Fraction of infected sites: 0.0
# Sweep: 421, Fraction of infected sites: 0.0
# Sweep: 422, Fraction of infected sites: 0.0
# Sweep: 423, Fraction of infected sites: 0.0
# Sweep: 424, Fraction of infected sites: 0.0
# Sweep: 425, Fraction of infected sites: 0.0
# Sweep: 426, Fraction of infected sites: 0.0
# Sweep: 427, Fraction of infected sites: 0.0
# Sweep: 428, Fraction of infected sites: 0.0
# Sweep: 429, Fraction of infected sites: 0.0
# Sweep: 430, Fraction of infected sites: 0.0
# Sweep: 431, Fraction of infected sites: 0.0
# Sweep: 432, Fraction of infected sites: 0.0
# Sweep: 433, Fraction of infected sites: 0.0
# Sweep: 434, Fraction of infected sites: 0.0
# Sweep: 435, Fraction of infected sites: 0.0
# Sweep: 436, Fraction of infected sites: 0.0
# Sweep: 437, Fraction of infected sites: 0.0
# Sweep: 438, Fraction of infected sites: 0.0
# Sweep: 439, Fraction of infected sites: 0.0
# Sweep: 440, Fraction of infected sites: 0.0
# Sweep: 441, Fraction of infected sites: 0.0
# Sweep: 442, Fraction of infected sites: 0.0
# Sweep: 443, Fraction of infected sites: 0.0
# Sweep: 444, Fraction of infected sites: 0.0
# Sweep: 445, Fraction of infected sites: 0.0
# Sweep: 446, Fraction of infected sites: 0.0
# Sweep: 447, Fraction of infected sites: 0.0
# Sweep: 448, Fraction of infected sites: 0.0
# Sweep: 449, Fraction of infected sites: 0.0
# Sweep: 450, Fraction of infected sites: 0.0
# Sweep: 451, Fraction of infected sites: 0.0
# Sweep: 452, Fraction of infected sites: 0.0
# Sweep: 453, Fraction of infected sites: 0.0
# Sweep: 454, Fraction of infected sites: 0.0
# Sweep: 455, Fraction of infected sites: 0.0
# Sweep: 456, Fraction of infected sites: 0.0
# Sweep: 457, Fraction of infected sites: 0.0
# Sweep: 458, Fraction of infected sites: 0.0
# Sweep: 459, Fraction of infected sites: 0.0
# Sweep: 460, Fraction of infected sites: 0.0
# Sweep: 461, Fraction of infected sites: 0.0
# Sweep: 462, Fraction of infected sites: 0.0
# Sweep: 463, Fraction of infected sites: 0.0
# Sweep: 464, Fraction of infected sites: 0.0
# Sweep: 465, Fraction of infected sites: 0.0
# Sweep: 466, Fraction of infected sites: 0.0
# Sweep: 467, Fraction of infected sites: 0.0
# Sweep: 468, Fraction of infected sites: 0.0
# Sweep: 469, Fraction of infected sites: 0.0
# Sweep: 470, Fraction of infected sites: 0.0
# Sweep: 471, Fraction of infected sites: 0.0
# Sweep: 472, Fraction of infected sites: 0.0
# Sweep: 473, Fraction of infected sites: 0.0
# Sweep: 474, Fraction of infected sites: 0.0
# Sweep: 475, Fraction of infected sites: 0.0
# Sweep: 476, Fraction of infected sites: 0.0
# Sweep: 477, Fraction of infected sites: 0.0
# Sweep: 478, Fraction of infected sites: 0.0
# Sweep: 479, Fraction of infected sites: 0.0
# Sweep: 480, Fraction of infected sites: 0.0
# Sweep: 481, Fraction of infected sites: 0.0
# Sweep: 482, Fraction of infected sites: 0.0
# Sweep: 483, Fraction of infected sites: 0.0
# Sweep: 484, Fraction of infected sites: 0.0
# Sweep: 485, Fraction of infected sites: 0.0
# Sweep: 486, Fraction of infected sites: 0.0
# Sweep: 487, Fraction of infected sites: 0.0
# Sweep: 488, Fraction of infected sites: 0.0
# Sweep: 489, Fraction of infected sites: 0.0
# Sweep: 490, Fraction of infected sites: 0.0
# Sweep: 491, Fraction of infected sites: 0.0
# Sweep: 492, Fraction of infected sites: 0.0
# Sweep: 493, Fraction of infected sites: 0.0
# Sweep: 494, Fraction of infected sites: 0.0
# Sweep: 495, Fraction of infected sites: 0.0
# Sweep: 496, Fraction of infected sites: 0.0
# Sweep: 497, Fraction of infected sites: 0.0
# Sweep: 498, Fraction of infected sites: 0.0
# Sweep: 499, Fraction of infected sites: 0.0
#
# Average Infection (Fraction): 0.042853
#
# Variance Infection (Fraction): 1.4728806363999996e-06
